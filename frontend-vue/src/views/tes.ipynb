# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('sample_hydroponic_data (1).csv')
df.head()
# Out:
#                                      id             timestamp  flowrate  \
# 0  019d0baf-28b4-7121-84c0-9c18a6b8a7bc  2026-01-01T00:00:00Z      2.88
# 1  019d0baf-28b4-7121-84c0-9c19f6e7dd72  2026-01-01T01:00:00Z      1.35
# 2  019d0baf-28b4-7121-84c0-9c1a7db40ec8  2026-01-01T02:00:00Z      2.00
# 3  019d0baf-28b4-7121-84c0-9c1b724239ad  2026-01-01T03:00:00Z      1.77
# 4  019d0baf-28b4-7121-84c0-9c1c5139eaac  2026-01-01T04:00:00Z      2.07
#
#    distance  moisture1  moisture2  moisture3  moisture4  moisture5  moisture6  \
# 0     12.84         34         45         23         78         81         63
# 1     13.34         61         91         74         89         79         83
# 2      6.83         59         20         36         89         73         81
# 3      5.68         71         83         92         83         93         71
# 4     12.80         32         68         50         92         99         60
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 10000 non-null  str
#  1   timestamp          10000 non-null  str
#  2   flowrate           10000 non-null  float64
#  3   distance           10000 non-null  float64
#  4   moisture1          10000 non-null  int64
#  5   moisture2          10000 non-null  int64
#  6   moisture3          10000 non-null  int64
#  7   moisture4          10000 non-null  int64
#  8   moisture5          10000 non-null  int64
#  9   moisture6          10000 non-null  int64
#  10  temperature_atas   10000 non-null  float64
#  11  temperature_bawah  10000 non-null  float64
#  12  humidity_atas      10000 non-null  float64
#  13  humidity_bawah     10000 non-null  float64
#  14  ph                 10000 non-null  float64
#  15  tds                10000 non-null  float64
# ...

# %%
df_tes = pd.read_csv('hydroponic_data.csv')
df_tes
# Out:
#                                         Id                 Timestamp  \
# 0     019d0baf-28b4-7121-84c0-9c18a6b8a7bc  2026-01-01T00:00:00.000Z
# 1     019d0baf-28b4-7121-84c0-9c19f6e7dd72  2026-01-01T01:00:00.000Z
# 2     019d0baf-28b4-7121-84c0-9c1a7db40ec8  2026-01-01T02:00:00.000Z
# 3     019d0baf-28b4-7121-84c0-9c1b724239ad  2026-01-01T03:00:00.000Z
# 4     019d0baf-28b4-7121-84c0-9c1c5139eaac  2026-01-01T04:00:00.000Z
# ...                                    ...                       ...
# 9995  019d0baf-2a7f-7678-a9f4-d408405d1d82  2027-02-21T11:00:00.000Z
# 9996  019d0baf-2a7f-7678-a9f4-d4091ec184a4  2027-02-21T12:00:00.000Z
# 9997  019d0baf-2a7f-7678-a9f4-d40a588636c7  2027-02-21T13:00:00.000Z
# 9998  019d0baf-2a7f-7678-a9f4-d40b9456011d  2027-02-21T14:00:00.000Z
# 9999  019d0baf-2a7f-7678-a9f4-d40c393723e5  2027-02-21T15:00:00.000Z
#
#       Moisture 1 (%)  Moisture 2 (%)  Moisture 3 (%)  Moisture 4 (%)  \
# ...

# %%
df_tes.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 10000 non-null  str
#  1   timestamp          10000 non-null  str
#  2   flowrate           10000 non-null  float64
#  3   distance           10000 non-null  float64
#  4   moisture1          10000 non-null  int64
#  5   moisture2          10000 non-null  int64
#  6   moisture3          10000 non-null  int64
#  7   moisture4          10000 non-null  int64
#  8   moisture5          10000 non-null  int64
#  9   moisture6          10000 non-null  int64
#  10  temperature_atas   10000 non-null  float64
#  11  temperature_bawah  10000 non-null  float64
#  12  humidity_atas      10000 non-null  float64
#  13  humidity_bawah     10000 non-null  float64
#  14  ph                 10000 non-null  float64
#  15  tds                10000 non-null  float64
# ...

# %%
df_data_sensor = pd.read_csv('hydroponic_data_sensor.csv')
df_data_sensor
# Out:
#                                         Id                 Timestamp  \
# 0     019d0baf-28b4-7121-84c0-9c18a6b8a7bc  2026-01-01T00:00:00.000Z
# 1     019d0baf-28b4-7121-84c0-9c19f6e7dd72  2026-01-01T01:00:00.000Z
# 2     019d0baf-28b4-7121-84c0-9c1a7db40ec8  2026-01-01T02:00:00.000Z
# 3     019d0baf-28b4-7121-84c0-9c1b724239ad  2026-01-01T03:00:00.000Z
# 4     019d0baf-28b4-7121-84c0-9c1c5139eaac  2026-01-01T04:00:00.000Z
# ...                                    ...                       ...
# 9995  019d0baf-2a7f-7678-a9f4-d408405d1d82  2027-02-21T11:00:00.000Z
# 9996  019d0baf-2a7f-7678-a9f4-d4091ec184a4  2027-02-21T12:00:00.000Z
# 9997  019d0baf-2a7f-7678-a9f4-d40a588636c7  2027-02-21T13:00:00.000Z
# 9998  019d0baf-2a7f-7678-a9f4-d40b9456011d  2027-02-21T14:00:00.000Z
# 9999  019d0baf-2a7f-7678-a9f4-d40c393723e5  2027-02-21T15:00:00.000Z
#
#       Moisture 1 (%)  Moisture 2 (%)  Moisture 3 (%)  Moisture 4 (%)  \
# ...

# %%
df_data_environment = pd.read_csv('hydroponic_data_environment.csv')
df_data_environment
# Out:
#                                         Id                 Timestamp    pH  \
# 0     019d0baf-28b4-7121-84c0-9c18a6b8a7bc  2026-01-01T00:00:00.000Z  6.57
# 1     019d0baf-28b4-7121-84c0-9c19f6e7dd72  2026-01-01T01:00:00.000Z  7.40
# 2     019d0baf-28b4-7121-84c0-9c1a7db40ec8  2026-01-01T02:00:00.000Z  6.28
# 3     019d0baf-28b4-7121-84c0-9c1b724239ad  2026-01-01T03:00:00.000Z  6.46
# 4     019d0baf-28b4-7121-84c0-9c1c5139eaac  2026-01-01T04:00:00.000Z  6.56
# ...                                    ...                       ...   ...
# 9995  019d0baf-2a7f-7678-a9f4-d408405d1d82  2027-02-21T11:00:00.000Z  7.28
# 9996  019d0baf-2a7f-7678-a9f4-d4091ec184a4  2027-02-21T12:00:00.000Z  6.52
# 9997  019d0baf-2a7f-7678-a9f4-d40a588636c7  2027-02-21T13:00:00.000Z  6.99
# 9998  019d0baf-2a7f-7678-a9f4-d40b9456011d  2027-02-21T14:00:00.000Z  6.89
# 9999  019d0baf-2a7f-7678-a9f4-d40c393723e5  2027-02-21T15:00:00.000Z  6.35
#
# ...

# %%
df_data_actuator = pd.read_csv('hydroponic_data_actuator.csv')
df_data_actuator
# Out:
#                                         Id                 Timestamp  \
# 0     019d0baf-28b4-7121-84c0-9c18a6b8a7bc  2026-01-01T00:00:00.000Z
# 1     019d0baf-28b4-7121-84c0-9c19f6e7dd72  2026-01-01T01:00:00.000Z
# 2     019d0baf-28b4-7121-84c0-9c1a7db40ec8  2026-01-01T02:00:00.000Z
# 3     019d0baf-28b4-7121-84c0-9c1b724239ad  2026-01-01T03:00:00.000Z
# 4     019d0baf-28b4-7121-84c0-9c1c5139eaac  2026-01-01T04:00:00.000Z
# ...                                    ...                       ...
# 9995  019d0baf-2a7f-7678-a9f4-d408405d1d82  2027-02-21T11:00:00.000Z
# 9996  019d0baf-2a7f-7678-a9f4-d4091ec184a4  2027-02-21T12:00:00.000Z
# 9997  019d0baf-2a7f-7678-a9f4-d40a588636c7  2027-02-21T13:00:00.000Z
# 9998  019d0baf-2a7f-7678-a9f4-d40b9456011d  2027-02-21T14:00:00.000Z
# 9999  019d0baf-2a7f-7678-a9f4-d40c393723e5  2027-02-21T15:00:00.000Z
#
#      Pump Status Light Status Automation Status
# 0             ON          OFF                ON
# ...
